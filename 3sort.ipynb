# %%
import pandas as pd

data = pd.read_csv('2.avg-harga_bahan_pokok_jawa_timur_2023.csv', sep=';')
print(data)

def selection_sort(data, column):
    for i in range(len(data)):
        min_idx = i
        for j in range(i+1, len(data)):
            if data.loc[j, column] < data.loc[min_idx, column]:
                min_idx = j
        data.iloc[i], data.iloc[min_idx] = data.iloc[min_idx].copy(), data.iloc[i].copy()
    return data

selection_sort(data, 'harga_rata_rata')
print(data)
# Out:
#     periode_update                                        bahan_pokok  \
# 0     Januari 2023                                 Beras Premium / kg
# 1     Januari 2023                                  Beras Mentik / kg
# 2     Januari 2023                                  Beras Medium / kg
# 3     Januari 2023                            Gula Kristal Putih / kg
# 4     Januari 2023  Minyak Goreng Bimoli Botol / Kemasan (Sps) 620 ml
# ..             ...                                                ...
# 807  Desember 2023                        Pupuk KCL  Non Subsidi / Kg
# 808  Desember 2023                         Pupuk NPK Non Subsidi / Kg
# 809  Desember 2023                       Pupuk SP 35 Non Subsidi / Kg
# 810  Desember 2023                        Pupuk Urea Non Subsidi / Kg
# 811  Desember 2023                          Pupuk ZA Non Subsidi / Kg
#
#     satuan_bapok  harga_rata_rata
# 0             kg            12210
# 1             kg            11958
# 2             kg            10587
# 3             kg            13059
# 4         620 ml            17087
# ..           ...              ...
# 807           Kg             9913
# 808           Kg            12000
# 809           Kg             7347
# 810           Kg             7631
# 811           Kg             6092
#
# [812 rows x 4 columns]
#     periode_update                     bahan_pokok satuan_bapok  \
# 0           Apr-23    Garam Beryodium  Bata / buah         Buah
# 1     Agustus 2023    Garam Beryodium  Bata / buah         Buah
# 2         Mei 2023    Garam Beryodium  Bata / buah         Buah
# 3        Juli 2023    Garam Beryodium  Bata / buah         Buah
# 4        Juni 2023    Garam Beryodium  Bata / buah         Buah
# ..             ...                             ...          ...
# 807      Juni 2023  Daging Sapi Paha Belakang / kg           kg
# 808         Nov-23  Daging Sapi Paha Belakang / kg           kg
# 809  Desember 2023  Daging Sapi Paha Belakang / kg           kg
# 810       Mei 2023  Daging Sapi Paha Belakang / kg           kg
# 811         Apr-23  Daging Sapi Paha Belakang / kg           kg
#
#      harga_rata_rata
# 0               1447
# 1               1466
# 2               1471
# 3               1474
# 4               1477
# ..               ...
# 807           116590
# 808           116677
# 809           116710
# 810           116926
# 811           117366
#
# [812 rows x 4 columns]

# %%
import pandas as pd

df = pd.read_csv('2.avg-harga_bahan_pokok_jawa_timur_2023.csv', sep=';')
print(data)

def quick_sort(data, column, low, high):
    if low < high:
        pi = partition(data, column, low, high)
        quick_sort(data, column, low, pi-1)
        quick_sort(data, column, pi+1, high)

def partition(data, column, low, high):
    i = low - 1
    pivot = data.loc[high, column]
    for j in range(low, high):
        if data.loc[j, column] <= pivot:
            i += 1
            data.iloc[i], data.iloc[j] = data.iloc[j].copy(), data.iloc[i].copy()
    data.iloc[i+1], data.iloc[high] = data.iloc[high].copy(), data.iloc[i+1].copy()
    return i + 1

quick_sort(data, 'harga_rata_rata', 0, len(data)-1)
print(data)
# Out:
#     periode_update                                        bahan_pokok  \
# 0     Januari 2023                                 Beras Premium / kg
# 1     Januari 2023                                  Beras Mentik / kg
# 2     Januari 2023                                  Beras Medium / kg
# 3     Januari 2023                            Gula Kristal Putih / kg
# 4     Januari 2023  Minyak Goreng Bimoli Botol / Kemasan (Sps) 620 ml
# ..             ...                                                ...
# 807  Desember 2023                        Pupuk KCL  Non Subsidi / Kg
# 808  Desember 2023                         Pupuk NPK Non Subsidi / Kg
# 809  Desember 2023                       Pupuk SP 35 Non Subsidi / Kg
# 810  Desember 2023                        Pupuk Urea Non Subsidi / Kg
# 811  Desember 2023                          Pupuk ZA Non Subsidi / Kg
#
#     satuan_bapok  harga_rata_rata
# 0             kg            12210
# 1             kg            11958
# 2             kg            10587
# 3             kg            13059
# 4         620 ml            17087
# ..           ...              ...
# 807           Kg             9913
# 808           Kg            12000
# 809           Kg             7347
# 810           Kg             7631
# 811           Kg             6092
#
# [812 rows x 4 columns]
#     periode_update                     bahan_pokok satuan_bapok  \
# 0           Apr-23    Garam Beryodium  Bata / buah         Buah
# 1     Agustus 2023    Garam Beryodium  Bata / buah         Buah
# 2         Mei 2023    Garam Beryodium  Bata / buah         Buah
# 3        Juli 2023    Garam Beryodium  Bata / buah         Buah
# 4        Juni 2023    Garam Beryodium  Bata / buah         Buah
# ..             ...                             ...          ...
# 807      Juni 2023  Daging Sapi Paha Belakang / kg           kg
# 808         Nov-23  Daging Sapi Paha Belakang / kg           kg
# 809  Desember 2023  Daging Sapi Paha Belakang / kg           kg
# 810       Mei 2023  Daging Sapi Paha Belakang / kg           kg
# 811         Apr-23  Daging Sapi Paha Belakang / kg           kg
#
#      harga_rata_rata
# 0               1447
# 1               1466
# 2               1471
# 3               1474
# 4               1477
# ..               ...
# 807           116590
# 808           116677
# 809           116710
# 810           116926
# 811           117366
#
# [812 rows x 4 columns]

# %%
import pandas as pd

data = pd.read_csv('2.avg-harga_bahan_pokok_jawa_timur_2023.csv', sep=';')
print(data)

def counting_sort(data, column):
    max_val = int(data[column].max())
    count = [0] * (max_val + 1)
    output = [0] * len(data)

    for i in data[column]:
        count[int(i)] += 1

    for i in range(1, len(count)):
        count[i] += count[i - 1]

    for i in range(len(data) - 1, -1, -1):
        output[count[int(data.loc[i, column])] - 1] = data.loc[i]
        count[int(data.loc[i, column])] -= 1

    for i in range(len(data)):
        data.loc[i] = output[i]

    return data

counting_sort(data, 'harga_rata_rata')
print(data)
# Out:
#     periode_update                                        bahan_pokok  \
# 0     Januari 2023                                 Beras Premium / kg
# 1     Januari 2023                                  Beras Mentik / kg
# 2     Januari 2023                                  Beras Medium / kg
# 3     Januari 2023                            Gula Kristal Putih / kg
# 4     Januari 2023  Minyak Goreng Bimoli Botol / Kemasan (Sps) 620 ml
# ..             ...                                                ...
# 807  Desember 2023                        Pupuk KCL  Non Subsidi / Kg
# 808  Desember 2023                         Pupuk NPK Non Subsidi / Kg
# 809  Desember 2023                       Pupuk SP 35 Non Subsidi / Kg
# 810  Desember 2023                        Pupuk Urea Non Subsidi / Kg
# 811  Desember 2023                          Pupuk ZA Non Subsidi / Kg
#
#     satuan_bapok  harga_rata_rata
# 0             kg            12210
# 1             kg            11958
# 2             kg            10587
# 3             kg            13059
# 4         620 ml            17087
# ..           ...              ...
# 807           Kg             9913
# 808           Kg            12000
# 809           Kg             7347
# 810           Kg             7631
# 811           Kg             6092
#
# [812 rows x 4 columns]
#     periode_update                     bahan_pokok satuan_bapok  \
# 0           Apr-23    Garam Beryodium  Bata / buah         Buah
# 1     Agustus 2023    Garam Beryodium  Bata / buah         Buah
# 2         Mei 2023    Garam Beryodium  Bata / buah         Buah
# 3        Juli 2023    Garam Beryodium  Bata / buah         Buah
# 4        Juni 2023    Garam Beryodium  Bata / buah         Buah
# ..             ...                             ...          ...
# 807      Juni 2023  Daging Sapi Paha Belakang / kg           kg
# 808         Nov-23  Daging Sapi Paha Belakang / kg           kg
# 809  Desember 2023  Daging Sapi Paha Belakang / kg           kg
# 810       Mei 2023  Daging Sapi Paha Belakang / kg           kg
# 811         Apr-23  Daging Sapi Paha Belakang / kg           kg
#
#      harga_rata_rata
# 0               1447
# 1               1466
# 2               1471
# 3               1474
# 4               1477
# ..               ...
# 807           116590
# 808           116677
# 809           116710
# 810           116926
# 811           117366
#
# [812 rows x 4 columns]
